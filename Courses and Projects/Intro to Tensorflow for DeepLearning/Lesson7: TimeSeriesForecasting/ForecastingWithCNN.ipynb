# %%
"""
In this nb, we are forecasting Time-Series with a Stateful LSTM(Long Short Term Memory) Model with CNN. 
Then, we see the Fully Convolutional Model which ends up being the best model so far to predict Time
Series.
"""

# Importing stuff
import numpy as np
import matplotlib.pyplot as plt
import tensorflow.compat.v2 as tf
keras = tf.keras

# A function to plot time-series. This will be called finally when complete series is built
def plot_series(time,series,format="-",start=0,end=None,label=None):
    plt.plot(time[start:end],series[start:end],format,label=label)
    plt.xlabel('Time')
    plt.ylabel('Value')
    if label:
        plt.legend(fontsize=14)
    plt.grid(True)
    
# Function to create a trend
def trend(time,slope=0):
    return slope*time

# Creating a time series
time = np.arange(4*365+1)
baseline = 10 #Base value for trend 

# Function which creates a random pattern. This pattern will be repeated to get a seasonal pattern
def seasonal_pattern(seasonal_time):
    return np.where(seasonal_time < 0.4,
                    1/np.exp(3*seasonal_time),
                    np.cos(seasonal_time*2*np.pi))

# Function to repeat seasonal pattern
def seasonality(time,period,amplitude=1,phase=0):
    season_time = ((time+phase) % period)/period
    return amplitude * seasonal_pattern(season_time)

# Function to create white noise. seed parameter here is used by random number generator as a base to create
# random number. When it is None, rnd will use system time as seed. But, if we give some constant value like 42,
# then every time same noise will be generated. Thus, to get different noise everytime keep seed as None even 
# while calling the function
def white_noise(time,noise_level=1,seed=None):
    rnd = np.random.RandomState(seed)
    return rnd.randn(len(time)) * noise_level

# Creating Seasonality 
amplitude = 50
series = seasonality(time,period=365,amplitude=amplitude) + baseline

# Creating White Noise
noise_level = 5
noise = white_noise(time,noise_level)

# Creating seasonality with trend
slope = 0.05
series = baseline + trend(time,slope) + seasonality(time,period=365,amplitude=amplitude)

# Finally plotting complete time-series
series += noise
plt.figure(figsize=(10,10))
plot_series(time,series,label="Time-Series")

# Creating Training and Validation data
split_time = 1000
time_train = time[:split_time]
x_train = series[:split_time]
time_valid = time[split_time:]
x_valid = series[split_time:]

# Function to apply our model to series(This will be validation series)
def model_forecast(model,series,window_size):
    ds = tf.data.Dataset.from_tensor_slices(series)
    ds = ds.window(window_size, shift=1, drop_remainder=True)
    ds = ds.flat_map(lambda window: window.batch(window_size))
    ds = ds.batch(32).prefetch(1)
    forecast = model.predict(ds)
    return forecast

# %%
# Function to create dataset in proper format for Seq2Seq Model
def seq2seq_window_dataset(series,window_size=30,batch_size=32,shuffle_buffer=1000):
    series = tf.expand_dims(series,axis=-1)
    ds = tf.data.Dataset.from_tensor_slices(series)
    ds = ds.window(window_size+1,shift=1,drop_remainder=True)
    ds = ds.flat_map(lambda window: window.batch(window_size+1))
    ds = ds.shuffle(shuffle_buffer)
    ds = ds.map(lambda x: (x[:-1],x[1:]))
    return ds.batch(batch_size).prefetch(1)

# %%
# Building the model Con1D followed by LSTM Architecture
tf.random.set_seed(42)
np.random.seed(42)

window_size=30
train_set = seq2seq_window_dataset(x_train,window_size, batch_size=128)

# Stateful LSTM Model, return_sequences=True makes first Recurrent layer to return output for each time-stamp
# Recurrent layers need 3-d input_shape, [batch_size, number of time stamps, dimensionality of input]
# tf.expand_dims add one more dimension of 1 since we are using uni-variate time series.
# This is required because window_dataset creates 2-d dataset
# stateful = True makes sure that the state of previous batch goes to the next one
model = tf.keras.Sequential([
    keras.layers.Conv1D(filters=32, strides=1, kernel_size=5, input_shape=[None,1], activation="relu",
                       padding="causal"),
    keras.layers.LSTM(100, return_sequences=True),
    keras.layers.LSTM(100, return_sequences=True),
    keras.layers.Dense(1),
    keras.layers.Lambda(lambda x: x * 200.0) #The output of RNN layers is normalised between [-1,1]
])

# We can use Learning Rate Scheduler which can show us at which lr model is giving better results
# After every 30 epochs lr is * by 10 power and model is evaluated using it
lr_schedule = keras.callbacks.LearningRateScheduler(lambda epoch: 1e-8 * 10 ** (epoch/20))

# Optimizer is Stochastic Gradient Descent
optimizer = keras.optimizers.SGD(lr=1e-8, momentum=0.9)
model.compile(loss=keras.losses.Huber(),
             optimizer=optimizer,
             metrics=['mae'])

history = model.fit(train_set,epochs=100,callbacks=[lr_schedule])

plt.semilogx(history.history['lr'],history.history['loss'])
# Out:
# Epoch 1/100
# 8/8 [==============================] - 8s 1s/step - loss: 53.7102 - mae: 54.7196
# Epoch 2/100
# 8/8 [==============================] - 2s 225ms/step - loss: 52.0676 - mae: 52.6177
# Epoch 3/100
# 8/8 [==============================] - 2s 209ms/step - loss: 48.7645 - mae: 49.0489
# Epoch 4/100
# 8/8 [==============================] - 2s 298ms/step - loss: 40.8932 - mae: 41.0552
# Epoch 5/100
# 8/8 [==============================] - 2s 234ms/step - loss: 28.7390 - mae: 28.9648
# Epoch 6/100
# 8/8 [==============================] - 2s 198ms/step - loss: 23.6893 - mae: 24.0139
# Epoch 7/100
# 8/8 [==============================] - 2s 292ms/step - loss: 21.9117 - mae: 22.4163
# Epoch 8/100
# 8/8 [==============================] - 2s 193ms/step - loss: 21.4321 - mae: 21.9046
# Epoch 9/100
# 8/8 [==============================] - 1s 185ms/step - loss: 20.9653 - mae: 21.5762
# Epoch 10/100
# 8/8 [==============================] - 2s 202ms/step - loss: 20.9369 - mae: 21.2313
# Epoch 11/100
# 8/8 [==============================] - 2s 189ms/step - loss: 20.3849 - mae: 20.8982
# Epoch 12/100
# 8/8 [==============================] - 2s 212ms/step - loss: 20.1611 - mae: 20.5905
# Epoch 13/100
# 8/8 [==============================] - 2s 242ms/step - loss: 19.8920 - mae: 20.2975
# Epoch 14/100
# 8/8 [==============================] - 1s 169ms/step - loss: 19.5820 - mae: 19.9973
# Epoch 15/100
# 8/8 [==============================] - 2s 212ms/step - loss: 19.1913 - mae: 19.6896
# Epoch 16/100
# 8/8 [==============================] - 2s 189ms/step - loss: 18.8814 - mae: 19.3716
# Epoch 17/100
# 8/8 [==============================] - 1s 176ms/step - loss: 18.5148 - mae: 19.0487
# Epoch 18/100
# 8/8 [==============================] - 1s 170ms/step - loss: 18.2892 - mae: 18.7134
# Epoch 19/100
# 8/8 [==============================] - 2s 198ms/step - loss: 17.7733 - mae: 18.3540
# Epoch 20/100
# 8/8 [==============================] - 2s 243ms/step - loss: 17.3941 - mae: 17.9960
# Epoch 21/100
# 8/8 [==============================] - 1s 179ms/step - loss: 17.0846 - mae: 17.6028
# Epoch 22/100
# 8/8 [==============================] - 1s 185ms/step - loss: 16.7579 - mae: 17.2014
# Epoch 23/100
# 8/8 [==============================] - 1s 163ms/step - loss: 16.3397 - mae: 16.7851
# Epoch 24/100
# 8/8 [==============================] - 2s 246ms/step - loss: 15.9591 - mae: 16.3557
# Epoch 25/100
# 8/8 [==============================] - 1s 184ms/step - loss: 15.4739 - mae: 15.8954
# Epoch 26/100
# 8/8 [==============================] - 2s 237ms/step - loss: 14.9221 - mae: 15.4334
# Epoch 27/100
# 8/8 [==============================] - 2s 204ms/step - loss: 14.5220 - mae: 14.9509
# Epoch 28/100
# 8/8 [==============================] - 2s 206ms/step - loss: 14.0373 - mae: 14.4521
# Epoch 29/100
# 8/8 [==============================] - 2s 239ms/step - loss: 13.4444 - mae: 13.9662
# Epoch 30/100
# 8/8 [==============================] - 2s 193ms/step - loss: 12.9667 - mae: 13.4599
# Epoch 31/100
# 8/8 [==============================] - 1s 186ms/step - loss: 12.5154 - mae: 12.9712
# Epoch 32/100
# 8/8 [==============================] - 2s 204ms/step - loss: 12.0287 - mae: 12.4755
# Epoch 33/100
# 8/8 [==============================] - 1s 180ms/step - loss: 11.4854 - mae: 11.9956
# Epoch 34/100
# 8/8 [==============================] - 2s 194ms/step - loss: 11.0131 - mae: 11.4816
# Epoch 35/100
# 8/8 [==============================] - 1s 174ms/step - loss: 10.5234 - mae: 10.9874
# Epoch 36/100
# 8/8 [==============================] - 1s 178ms/step - loss: 10.0576 - mae: 10.6029
# Epoch 37/100
# 8/8 [==============================] - 1s 179ms/step - loss: 9.9052 - mae: 10.4128
# Epoch 38/100
# 8/8 [==============================] - 2s 190ms/step - loss: 9.7702 - mae: 10.3401
# Epoch 39/100
# 8/8 [==============================] - 1s 175ms/step - loss: 10.4525 - mae: 10.9419
# Epoch 40/100
# 8/8 [==============================] - 2s 192ms/step - loss: 10.1110 - mae: 10.5587
# Epoch 41/100
# 8/8 [==============================] - 1s 176ms/step - loss: 9.5354 - mae: 10.0414
# Epoch 42/100
# 8/8 [==============================] - 1s 178ms/step - loss: 9.2354 - mae: 9.7432
# Epoch 43/100
# 8/8 [==============================] - 2s 251ms/step - loss: 8.9957 - mae: 9.4823
# Epoch 44/100
# 8/8 [==============================] - 2s 236ms/step - loss: 8.7004 - mae: 9.1962
# Epoch 45/100
# 8/8 [==============================] - 1s 177ms/step - loss: 8.4618 - mae: 8.9246
# Epoch 46/100
# 8/8 [==============================] - 1s 184ms/step - loss: 8.1262 - mae: 8.5918
# Epoch 47/100
# 8/8 [==============================] - 1s 177ms/step - loss: 7.8104 - mae: 8.2874
# Epoch 48/100
# 8/8 [==============================] - 2s 191ms/step - loss: 7.5203 - mae: 8.0113
# Epoch 49/100
# 8/8 [==============================] - 2s 243ms/step - loss: 7.3618 - mae: 7.8098
# Epoch 50/100
# 8/8 [==============================] - 2s 189ms/step - loss: 7.0847 - mae: 7.5720
# Epoch 51/100
# 8/8 [==============================] - 1s 180ms/step - loss: 6.9659 - mae: 7.4364
# Epoch 52/100
# 8/8 [==============================] - 2s 243ms/step - loss: 6.8599 - mae: 7.3584
# Epoch 53/100
# 8/8 [==============================] - 2s 237ms/step - loss: 6.6789 - mae: 7.1387
# Epoch 54/100
# 8/8 [==============================] - 2s 247ms/step - loss: 6.5438 - mae: 7.0307
# Epoch 55/100
# 8/8 [==============================] - 2s 189ms/step - loss: 6.3967 - mae: 6.8947
# Epoch 56/100
# 8/8 [==============================] - 1s 182ms/step - loss: 6.3103 - mae: 6.7933
# Epoch 57/100
# 8/8 [==============================] - 1s 187ms/step - loss: 6.1632 - mae: 6.6419
# Epoch 58/100
# 8/8 [==============================] - 1s 182ms/step - loss: 6.4029 - mae: 6.8514
# Epoch 59/100
# 8/8 [==============================] - 1s 187ms/step - loss: 5.9875 - mae: 6.5330
# Epoch 60/100
# 8/8 [==============================] - 1s 187ms/step - loss: 6.6570 - mae: 7.0951
# Epoch 61/100
# 8/8 [==============================] - 1s 186ms/step - loss: 6.1995 - mae: 6.6836
# Epoch 62/100
# 8/8 [==============================] - 2s 199ms/step - loss: 6.3193 - mae: 6.7920
# Epoch 63/100
# 8/8 [==============================] - 2s 188ms/step - loss: 7.4618 - mae: 7.9503
# Epoch 64/100
# 8/8 [==============================] - 2s 196ms/step - loss: 6.2854 - mae: 6.8369
# Epoch 65/100
# 8/8 [==============================] - 1s 180ms/step - loss: 6.4435 - mae: 6.9184
# Epoch 66/100
# 8/8 [==============================] - 1s 181ms/step - loss: 7.5404 - mae: 8.0118
# Epoch 67/100
# 8/8 [==============================] - 2s 191ms/step - loss: 7.2339 - mae: 7.8456
# Epoch 68/100
# 8/8 [==============================] - 2s 213ms/step - loss: 7.5380 - mae: 7.9967
# Epoch 69/100
# 8/8 [==============================] - 1s 183ms/step - loss: 8.0588 - mae: 8.4976
# Epoch 70/100
# 8/8 [==============================] - 1s 183ms/step - loss: 8.5479 - mae: 8.8356
# Epoch 71/100
# 8/8 [==============================] - 1s 182ms/step - loss: 8.8966 - mae: 10.3608
# Epoch 72/100
# 8/8 [==============================] - 1s 180ms/step - loss: 32.1584 - mae: 31.2890
# Epoch 73/100
# 8/8 [==============================] - 2s 190ms/step - loss: 17.4285 - mae: 18.1538
# Epoch 74/100
# 8/8 [==============================] - 1s 186ms/step - loss: 12.9863 - mae: 13.0352
# Epoch 75/100
# 8/8 [==============================] - 1s 182ms/step - loss: 8.9934 - mae: 9.4004
# Epoch 76/100
# 8/8 [==============================] - 2s 192ms/step - loss: 6.8043 - mae: 7.2151
# Epoch 77/100
# 8/8 [==============================] - 1s 184ms/step - loss: 8.7811 - mae: 9.0953
# Epoch 78/100
# 8/8 [==============================] - 1s 187ms/step - loss: 9.3931 - mae: 9.7286
# Epoch 79/100
# 8/8 [==============================] - 1s 180ms/step - loss: 10.0076 - mae: 10.4876
# Epoch 80/100
# 8/8 [==============================] - 1s 178ms/step - loss: 9.8584 - mae: 10.2649
# Epoch 81/100
# 8/8 [==============================] - 1s 183ms/step - loss: 9.8986 - mae: 10.2397
# Epoch 82/100
# 8/8 [==============================] - 2s 189ms/step - loss: 12.0153 - mae: 13.2377
# Epoch 83/100
# 8/8 [==============================] - 1s 184ms/step - loss: 23.0046 - mae: 23.5546
# Epoch 84/100
# 8/8 [==============================] - 1s 187ms/step - loss: 19.4757 - mae: 19.9694
# Epoch 85/100
# 8/8 [==============================] - 1s 186ms/step - loss: 19.7536 - mae: 19.9787
# Epoch 86/100
# 8/8 [==============================] - 2s 193ms/step - loss: 16.3986 - mae: 16.5174
# Epoch 87/100
# 8/8 [==============================] - 1s 184ms/step - loss: 8.7739 - mae: 9.3322
# Epoch 88/100
# 8/8 [==============================] - 1s 180ms/step - loss: 8.2486 - mae: 8.6738
# Epoch 89/100
# 8/8 [==============================] - 2s 192ms/step - loss: 9.8162 - mae: 10.0213
# Epoch 90/100
# 8/8 [==============================] - 1s 180ms/step - loss: 9.1256 - mae: 9.7006
# Epoch 91/100
# 8/8 [==============================] - 2s 190ms/step - loss: 8.1774 - mae: 9.2323
# Epoch 92/100
# 8/8 [==============================] - 2s 190ms/step - loss: 9.5813 - mae: 10.2360
# Epoch 93/100
# 8/8 [==============================] - 1s 183ms/step - loss: 7.9034 - mae: 9.0915
# Epoch 94/100
# 8/8 [==============================] - 1s 186ms/step - loss: 11.4054 - mae: 11.6272
# Epoch 95/100
# 8/8 [==============================] - 1s 179ms/step - loss: 12.8483 - mae: 12.9934
# Epoch 96/100
# 8/8 [==============================] - 1s 183ms/step - loss: 12.8320 - mae: 13.6666
# Epoch 97/100
# 8/8 [==============================] - 1s 178ms/step - loss: 14.2160 - mae: 14.4601
# Epoch 98/100
# 8/8 [==============================] - 1s 182ms/step - loss: 15.1568 - mae: 15.1807
# Epoch 99/100
# 8/8 [==============================] - 1s 182ms/step - loss: 17.0487 - mae: 18.8260
# Epoch 100/100
# 8/8 [==============================] - 1s 183ms/step - loss: 18.7459 - mae: 21.9243

# %%
# Building the model
tf.random.set_seed(42)
np.random.seed(42)

window_size=30
train_set = seq2seq_window_dataset(x_train,window_size)
valid_set = seq2seq_window_dataset(x_valid,window_size)

# Simple RNN Model, return_sequences=True makes first Recurrent layer to return output for each time-stamp
# Recurrent layers need 3-d input_shape, [batch_size, number of time stamps, dimensionality of input]
# tf.expand_dims add one more dimension of 1 since we are using uni-variate time series.
# This is required because window_dataset creates 2-d dataset
# stateful = True makes sure that the state of previous batch goes to the next one
model = tf.keras.Sequential([
    keras.layers.Conv1D(filters=32, kernel_size=5,
                      strides=1, padding="causal",
                      activation='relu', input_shape=[None,1]),
    keras.layers.LSTM(100, return_sequences=True),
    keras.layers.LSTM(100, return_sequences=True),
    keras.layers.Dense(1),
    keras.layers.Lambda(lambda x: x * 200.0) #The output of RNN layers is normalised between [-1,1]
])

# Stops training if metric stays same for 50 epochs on valid_set
early_stopper = keras.callbacks.EarlyStopping(patience=50)

# Saves the best model(model with best parameters) as "my_checkpoint.h5" so that we can load this model at end
model_checkpoint = keras.callbacks.ModelCheckpoint("my_checkpoint.h5", save_best_only = True)

# Optimizer is Stochastic Gradient Descent
optimizer = keras.optimizers.SGD(lr=1e-6, momentum=0.9)
model.compile(loss=keras.losses.Huber(),
             optimizer=optimizer,
             metrics=['mae'])

history = model.fit(train_set,epochs=100,validation_data=valid_set,callbacks=[early_stopper])
# Out:
# Epoch 1/100
# 31/31 [==============================] - 11s 352ms/step - loss: 22.9594 - mae: 23.6416 - val_loss: 0.0000e+00 - val_mae: 0.0000e+00
# Epoch 2/100
# 31/31 [==============================] - 3s 103ms/step - loss: 11.7174 - mae: 11.9001 - val_loss: 14.0729 - val_mae: 14.5213
# Epoch 3/100
# 31/31 [==============================] - 4s 118ms/step - loss: 10.0304 - mae: 10.4351 - val_loss: 13.5132 - val_mae: 14.0497
# Epoch 4/100
# 31/31 [==============================] - 3s 95ms/step - loss: 9.2610 - mae: 9.6055 - val_loss: 13.7457 - val_mae: 14.2124
# Epoch 5/100
# 31/31 [==============================] - 3s 92ms/step - loss: 8.5458 - mae: 8.9506 - val_loss: 12.9544 - val_mae: 13.3379
# Epoch 6/100
# 31/31 [==============================] - 3s 94ms/step - loss: 8.1188 - mae: 8.4602 - val_loss: 12.4429 - val_mae: 12.8882
# Epoch 7/100
# 31/31 [==============================] - 3s 91ms/step - loss: 7.6163 - mae: 8.0852 - val_loss: 11.0057 - val_mae: 11.4885
# Epoch 8/100
# 31/31 [==============================] - 3s 95ms/step - loss: 7.3379 - mae: 7.7867 - val_loss: 11.0350 - val_mae: 11.5420
# Epoch 9/100
# 31/31 [==============================] - 3s 91ms/step - loss: 7.0989 - mae: 7.5726 - val_loss: 11.0418 - val_mae: 11.5125
# Epoch 10/100
# 31/31 [==============================] - 3s 88ms/step - loss: 7.0008 - mae: 7.4147 - val_loss: 10.3426 - val_mae: 10.8514
# Epoch 11/100
# 31/31 [==============================] - 4s 115ms/step - loss: 6.7704 - mae: 7.2466 - val_loss: 9.4405 - val_mae: 9.9317
# Epoch 12/100
# 31/31 [==============================] - 4s 144ms/step - loss: 6.6275 - mae: 7.1181 - val_loss: 9.6556 - val_mae: 10.1510
# Epoch 13/100
# 31/31 [==============================] - 5s 149ms/step - loss: 6.4975 - mae: 7.0235 - val_loss: 9.3839 - val_mae: 9.9394
# Epoch 14/100
# 31/31 [==============================] - 4s 145ms/step - loss: 6.4514 - mae: 6.9334 - val_loss: 9.1377 - val_mae: 9.7071
# Epoch 15/100
# 31/31 [==============================] - 5s 152ms/step - loss: 6.3668 - mae: 6.8538 - val_loss: 9.2235 - val_mae: 9.7202
# Epoch 16/100
# 31/31 [==============================] - 3s 101ms/step - loss: 6.3591 - mae: 6.7912 - val_loss: 8.4931 - val_mae: 8.9636
# Epoch 17/100
# 31/31 [==============================] - 3s 90ms/step - loss: 6.1759 - mae: 6.7172 - val_loss: 8.2883 - val_mae: 8.7895
# Epoch 18/100
# 31/31 [==============================] - 3s 104ms/step - loss: 6.2221 - mae: 6.6696 - val_loss: 8.2611 - val_mae: 8.7148
# Epoch 19/100
# 31/31 [==============================] - 3s 91ms/step - loss: 6.1320 - mae: 6.6099 - val_loss: 8.1901 - val_mae: 8.7063
# Epoch 20/100
# 31/31 [==============================] - 3s 96ms/step - loss: 6.0455 - mae: 6.5536 - val_loss: 8.1312 - val_mae: 8.6391
# Epoch 21/100
# 31/31 [==============================] - 4s 113ms/step - loss: 6.0364 - mae: 6.5125 - val_loss: 7.9638 - val_mae: 8.4212
# Epoch 22/100
# 31/31 [==============================] - 4s 123ms/step - loss: 6.0423 - mae: 6.4660 - val_loss: 8.0162 - val_mae: 8.4635
# Epoch 23/100
# 31/31 [==============================] - 3s 99ms/step - loss: 5.9499 - mae: 6.4297 - val_loss: 8.1862 - val_mae: 8.6259
# Epoch 24/100
# 31/31 [==============================] - 3s 88ms/step - loss: 5.8935 - mae: 6.3909 - val_loss: 7.7504 - val_mae: 8.2406
# Epoch 25/100
# Epoch 86/100
# 31/31 [==============================] - 3s 107ms/step - loss: 5.1339 - mae: 5.5935 - val_loss: 6.6382 - val_mae: 7.1493
# Epoch 87/100
# 31/31 [==============================] - 3s 94ms/step - loss: 5.0920 - mae: 5.5829 - val_loss: 6.5187 - val_mae: 6.9831
# Epoch 88/100
# 31/31 [==============================] - 3s 89ms/step - loss: 5.0991 - mae: 5.5763 - val_loss: 6.8437 - val_mae: 7.3328
# Epoch 89/100
# 31/31 [==============================] - 3s 88ms/step - loss: 5.1087 - mae: 5.5726 - val_loss: 6.6412 - val_mae: 7.1443
# Epoch 90/100
# 31/31 [==============================] - 3s 89ms/step - loss: 5.0957 - mae: 5.5663 - val_loss: 6.7487 - val_mae: 7.2136
# Epoch 91/100
# 31/31 [==============================] - 3s 106ms/step - loss: 5.0880 - mae: 5.5639 - val_loss: 6.6167 - val_mae: 7.1145
# Epoch 92/100
# 31/31 [==============================] - 3s 103ms/step - loss: 5.0740 - mae: 5.5579 - val_loss: 6.3802 - val_mae: 6.8662
# Epoch 93/100
# 31/31 [==============================] - 3s 88ms/step - loss: 5.0739 - mae: 5.5489 - val_loss: 6.5830 - val_mae: 7.0817
# Epoch 94/100
# 31/31 [==============================] - 3s 89ms/step - loss: 5.0950 - mae: 5.5440 - val_loss: 6.4743 - val_mae: 6.9607
# Epoch 95/100
# 31/31 [==============================] - 3s 90ms/step - loss: 5.0406 - mae: 5.5422 - val_loss: 6.3637 - val_mae: 6.8477
# Epoch 96/100
# 31/31 [==============================] - 3s 91ms/step - loss: 5.0733 - mae: 5.5505 - val_loss: 6.6438 - val_mae: 7.0783
# Epoch 97/100
# 31/31 [==============================] - 3s 88ms/step - loss: 5.0616 - mae: 5.5355 - val_loss: 6.4328 - val_mae: 6.9131
# Epoch 98/100
# 31/31 [==============================] - 3s 96ms/step - loss: 5.0347 - mae: 5.5270 - val_loss: 6.4996 - val_mae: 6.9863
# Epoch 99/100
# 31/31 [==============================] - 3s 109ms/step - loss: 5.0352 - mae: 5.5221 - val_loss: 6.5343 - val_mae: 7.0451
# Epoch 100/100
# 31/31 [==============================] - 4s 114ms/step - loss: 5.0363 - mae: 5.5186 - val_loss: 6.8380 - val_mae: 7.3636

# %%
model = keras.models.load_model("my_checkpoint.h5")

# %%
model.reset_states()
# We're forecasting on complete series and then cropping out only the validation part for plotting
rnn_forecast = model.predict(series[np.newaxis,:,np.newaxis])[0,split_time-1:-1,0]

# %%
plt.figure(figsize=(10,10))
plot_series(time_valid,x_valid,label="Series")
plot_series(time_valid,rnn_forecast,label="Forecast")

keras.metrics.mean_absolute_error(x_valid,rnn_forecast).numpy()
# MAE is 4.54 :)
# Out:
# 4.5491962

# %%
# Building the fully Convolutional Model
tf.random.set_seed(42)
np.random.seed(42)

window_size=30
train_set = seq2seq_window_dataset(x_train,window_size, batch_size=128)

# Wavenet architecture with dilation_rate doubling for every Convolutional layer
model = tf.keras.Sequential([
    keras.layers.InputLayer(input_shape=[None,1])])
for dilation_rate in (1,2,4,8,16,32):
    model.add(keras.layers.Conv1D(
                                 filters=32, kernel_size=2,
                                 strides=1, dilation_rate=dilation_rate,
                                 padding="causal", activation="relu")
                                 )
model.add(keras.layers.Conv1D(filters=1, kernel_size=1))
    

# We can use Learning Rate Scheduler which can show us at which lr model is giving better results
# After every 30 epochs lr is * by 10 power and model is evaluated using it
lr_schedule = keras.callbacks.LearningRateScheduler(lambda epoch: 1e-8 * 10 ** (epoch/20))

# Optimizer is Stochastic Gradient Descent
optimizer = keras.optimizers.SGD(lr=1e-8, momentum=0.9)
model.compile(loss=keras.losses.Huber(),
             optimizer=optimizer,
             metrics=['mae'])

history = model.fit(train_set,epochs=100,callbacks=[lr_schedule])

plt.semilogx(history.history['lr'],history.history['loss'])
# Out:
# Epoch 1/100
# 8/8 [==============================] - 3s 337ms/step - loss: 45.2803 - mae: 46.1531
# Epoch 2/100
# 8/8 [==============================] - 0s 58ms/step - loss: 45.4524 - mae: 46.1530
# Epoch 3/100
# 8/8 [==============================] - 0s 59ms/step - loss: 45.7390 - mae: 46.1530
# Epoch 4/100
# 8/8 [==============================] - 0s 56ms/step - loss: 45.3605 - mae: 46.1528
# Epoch 5/100
# 8/8 [==============================] - 0s 58ms/step - loss: 45.8235 - mae: 46.1527
# Epoch 6/100
# 8/8 [==============================] - 1s 73ms/step - loss: 45.6920 - mae: 46.1525
# Epoch 7/100
# 8/8 [==============================] - 1s 85ms/step - loss: 45.4847 - mae: 46.1524
# Epoch 8/100
# 8/8 [==============================] - 1s 68ms/step - loss: 45.6440 - mae: 46.1522
# Epoch 9/100
# 8/8 [==============================] - 0s 62ms/step - loss: 45.3839 - mae: 46.1520
# Epoch 10/100
# 8/8 [==============================] - 0s 60ms/step - loss: 45.8719 - mae: 46.1517
# Epoch 11/100
# 8/8 [==============================] - 1s 73ms/step - loss: 45.6035 - mae: 46.1514
# Epoch 12/100
# 8/8 [==============================] - 1s 63ms/step - loss: 45.7389 - mae: 46.1511
# Epoch 13/100
# 8/8 [==============================] - 0s 58ms/step - loss: 46.0899 - mae: 46.1508
# Epoch 14/100
# 8/8 [==============================] - 0s 57ms/step - loss: 45.8005 - mae: 46.1504
# Epoch 15/100
# 8/8 [==============================] - 0s 58ms/step - loss: 45.8328 - mae: 46.1500
# Epoch 16/100
# 8/8 [==============================] - 0s 62ms/step - loss: 45.8205 - mae: 46.1495
# Epoch 17/100
# 8/8 [==============================] - 0s 61ms/step - loss: 45.5458 - mae: 46.1489
# Epoch 18/100
# 8/8 [==============================] - 1s 64ms/step - loss: 45.7273 - mae: 46.1483
# Epoch 19/100
# 8/8 [==============================] - 0s 60ms/step - loss: 45.6024 - mae: 46.1476
# Epoch 20/100
# 8/8 [==============================] - 0s 62ms/step - loss: 45.2911 - mae: 46.1468
# Epoch 21/100
# 8/8 [==============================] - 0s 59ms/step - loss: 45.3639 - mae: 46.1460
# Epoch 22/100
# 8/8 [==============================] - 1s 75ms/step - loss: 45.6338 - mae: 46.1450
# Epoch 23/100
# 8/8 [==============================] - 0s 61ms/step - loss: 45.9767 - mae: 46.1439
# Epoch 24/100
# 8/8 [==============================] - 1s 72ms/step - loss: 46.0817 - mae: 46.1427
# Epoch 25/100
# 8/8 [==============================] - 1s 66ms/step - loss: 45.8769 - mae: 46.1413
# Epoch 85/100
# 8/8 [==============================] - 1s 63ms/step - loss: 9.9575 - mae: 10.3994
# Epoch 86/100
# 8/8 [==============================] - 0s 58ms/step - loss: 9.3903 - mae: 9.9234
# Epoch 87/100
# 8/8 [==============================] - 0s 60ms/step - loss: 8.9864 - mae: 9.4580
# Epoch 88/100
# 8/8 [==============================] - 0s 61ms/step - loss: 8.5331 - mae: 8.9977
# Epoch 89/100
# 8/8 [==============================] - 0s 57ms/step - loss: 8.1391 - mae: 8.5936
# Epoch 90/100
# 8/8 [==============================] - 0s 58ms/step - loss: 7.8659 - mae: 8.3260
# Epoch 91/100
# 8/8 [==============================] - 0s 61ms/step - loss: 7.7023 - mae: 8.1665
# Epoch 92/100
# 8/8 [==============================] - 0s 56ms/step - loss: 7.6091 - mae: 8.0567
# Epoch 93/100
# 8/8 [==============================] - 0s 58ms/step - loss: 7.5515 - mae: 7.9590
# Epoch 94/100
# 8/8 [==============================] - 0s 60ms/step - loss: 7.3706 - mae: 7.8757
# Epoch 95/100
# 8/8 [==============================] - 0s 59ms/step - loss: 7.2972 - mae: 7.7991
# Epoch 96/100
# 8/8 [==============================] - 0s 60ms/step - loss: 7.2671 - mae: 7.7289
# Epoch 97/100
# 8/8 [==============================] - 0s 58ms/step - loss: 7.2284 - mae: 7.6693
# Epoch 98/100
# 8/8 [==============================] - 1s 68ms/step - loss: 7.5033 - mae: 7.9641
# Epoch 99/100
# 8/8 [==============================] - 0s 60ms/step - loss: 7.1150 - mae: 7.5556
# Epoch 100/100
# 8/8 [==============================] - 0s 58ms/step - loss: 7.3198 - mae: 7.9063

# %%
# Building the fully Convolutional Model
tf.random.set_seed(42)
np.random.seed(42)

window_size=30
train_set = seq2seq_window_dataset(x_train,window_size, batch_size=128)
valid_set = seq2seq_window_dataset(x_valid,window_size, batch_size=128)

# Wavenet architecture with dilation_rate doubling for every Convolutional layer
model = tf.keras.Sequential([
    keras.layers.InputLayer(input_shape=[None,1])])
for dilation_rate in (1,2,4,8,16,32):
    model.add(keras.layers.Conv1D(
                                 filters=32, kernel_size=2,
                                 strides=1, dilation_rate=dilation_rate,
                                 padding="causal", activation="relu")
                                 )
model.add(keras.layers.Conv1D(filters=1, kernel_size=1))
    

# Optimizer is Stochastic Gradient Descent
optimizer = keras.optimizers.SGD(lr=1e-4, momentum=0.9)
model.compile(loss=keras.losses.Huber(),
             optimizer=optimizer,
             metrics=['mae'])

# Stops training if metric stays same for 50 epochs on valid_set
early_stopper = keras.callbacks.EarlyStopping(patience=50)

# Saves the best model(model with best parameters) as "my_checkpoint.h5" so that we can load this model at end
model_checkpoint = keras.callbacks.ModelCheckpoint("my_checkpoint.h5", save_best_only = True)

history = model.fit(train_set,validation_data=valid_set,epochs=100,callbacks=[early_stopper, model_checkpoint])
# Out:
# Epoch 1/100
# 8/8 [==============================] - 3s 359ms/step - loss: 44.3799 - mae: 45.2420 - val_loss: 0.0000e+00 - val_mae: 0.0000e+00
# Epoch 2/100
# 8/8 [==============================] - 1s 76ms/step - loss: 44.1768 - mae: 44.9424 - val_loss: 79.6628 - val_mae: 80.3511
# Epoch 3/100
# 8/8 [==============================] - 1s 76ms/step - loss: 44.2281 - mae: 44.3980 - val_loss: 78.6052 - val_mae: 78.8337
# Epoch 4/100
# 8/8 [==============================] - 1s 75ms/step - loss: 42.6736 - mae: 43.5056 - val_loss: 75.8476 - val_mae: 76.3579
# Epoch 5/100
# 8/8 [==============================] - 1s 76ms/step - loss: 42.1724 - mae: 41.8597 - val_loss: 70.8606 - val_mae: 70.9534
# Epoch 6/100
# 8/8 [==============================] - 1s 78ms/step - loss: 38.0814 - mae: 37.7993 - val_loss: 55.2794 - val_mae: 56.0383
# Epoch 7/100
# 8/8 [==============================] - 1s 75ms/step - loss: 26.6006 - mae: 25.2924 - val_loss: 30.0274 - val_mae: 30.1630
# Epoch 8/100
# 8/8 [==============================] - 1s 84ms/step - loss: 21.3125 - mae: 21.2794 - val_loss: 21.7531 - val_mae: 22.2898
# Epoch 9/100
# 8/8 [==============================] - 1s 132ms/step - loss: 16.2726 - mae: 16.9256 - val_loss: 17.5968 - val_mae: 18.0705
# Epoch 10/100
# 8/8 [==============================] - 1s 75ms/step - loss: 13.7956 - mae: 13.9321 - val_loss: 14.8503 - val_mae: 15.3424
# Epoch 11/100
# 8/8 [==============================] - 1s 89ms/step - loss: 11.6981 - mae: 11.8986 - val_loss: 11.1467 - val_mae: 11.6699
# Epoch 12/100
# 8/8 [==============================] - 1s 93ms/step - loss: 10.6615 - mae: 11.1176 - val_loss: 10.9718 - val_mae: 11.3835
# Epoch 13/100
# 8/8 [==============================] - 1s 112ms/step - loss: 10.1385 - mae: 10.6220 - val_loss: 9.3923 - val_mae: 9.9035
# Epoch 14/100
# 8/8 [==============================] - 1s 76ms/step - loss: 9.5382 - mae: 10.0364 - val_loss: 8.5657 - val_mae: 9.0805
# Epoch 15/100
# 8/8 [==============================] - 1s 95ms/step - loss: 9.1464 - mae: 9.6660 - val_loss: 7.9873 - val_mae: 8.4764
# Epoch 16/100
# 8/8 [==============================] - 1s 109ms/step - loss: 9.0791 - mae: 9.3608 - val_loss: 7.4568 - val_mae: 7.9635
# Epoch 17/100
# 8/8 [==============================] - 1s 93ms/step - loss: 8.4617 - mae: 9.1092 - val_loss: 7.0185 - val_mae: 7.5252
# Epoch 18/100
# 8/8 [==============================] - 1s 100ms/step - loss: 8.4483 - mae: 8.9105 - val_loss: 6.7108 - val_mae: 7.1866
# Epoch 19/100
# 8/8 [==============================] - 1s 114ms/step - loss: 8.3418 - mae: 8.7488 - val_loss: 6.4852 - val_mae: 6.9169
# Epoch 20/100
# 8/8 [==============================] - 1s 105ms/step - loss: 8.1166 - mae: 8.6233 - val_loss: 6.2526 - val_mae: 6.7428
# Epoch 21/100
# 8/8 [==============================] - 1s 121ms/step - loss: 8.0346 - mae: 8.5329 - val_loss: 6.0673 - val_mae: 6.5998
# Epoch 22/100
# 8/8 [==============================] - 1s 101ms/step - loss: 8.1421 - mae: 8.4638 - val_loss: 5.9921 - val_mae: 6.4988
# Epoch 23/100
# 8/8 [==============================] - 1s 78ms/step - loss: 7.8395 - mae: 8.4069 - val_loss: 5.9658 - val_mae: 6.4219
# Epoch 24/100
# 8/8 [==============================] - 1s 79ms/step - loss: 7.6984 - mae: 8.3529 - val_loss: 5.8984 - val_mae: 6.3542
# Epoch 25/100
# 8/8 [==============================] - 1s 94ms/step - loss: 7.7543 - mae: 8.3100 - val_loss: 5.8181 - val_mae: 6.2941
# Epoch 26/100
# 8/8 [==============================] - 1s 94ms/step - loss: 7.7326 - mae: 8.2681 - val_loss: 5.7633 - val_mae: 6.2424
# Epoch 27/100
# 8/8 [==============================] - 1s 79ms/step - loss: 7.5070 - mae: 8.2294 - val_loss: 5.6858 - val_mae: 6.1870
# Epoch 28/100
# 8/8 [==============================] - 1s 78ms/step - loss: 7.6976 - mae: 8.1934 - val_loss: 5.6240 - val_mae: 6.1339
# Epoch 29/100
# 8/8 [==============================] - 1s 72ms/step - loss: 7.6176 - mae: 8.1583 - val_loss: 5.6530 - val_mae: 6.0839
# Epoch 30/100
# 8/8 [==============================] - 1s 76ms/step - loss: 7.8391 - mae: 8.1259 - val_loss: 5.5587 - val_mae: 6.0406
# Epoch 31/100
# 8/8 [==============================] - 1s 97ms/step - loss: 7.7246 - mae: 8.0947 - val_loss: 5.5418 - val_mae: 6.0091
# Epoch 32/100
# 8/8 [==============================] - 1s 81ms/step - loss: 7.4447 - mae: 8.0652 - val_loss: 5.4496 - val_mae: 5.9505
# Epoch 33/100
# 8/8 [==============================] - 1s 122ms/step - loss: 7.6080 - mae: 8.0355 - val_loss: 5.4352 - val_mae: 5.9085
# Epoch 34/100
# 8/8 [==============================] - 1s 74ms/step - loss: 7.4888 - mae: 8.0101 - val_loss: 5.3674 - val_mae: 5.8692
# Epoch 35/100
# 8/8 [==============================] - 1s 82ms/step - loss: 7.3345 - mae: 7.9853 - val_loss: 5.3568 - val_mae: 5.8356
# Epoch 36/100
# 8/8 [==============================] - 1s 92ms/step - loss: 7.6994 - mae: 7.9612 - val_loss: 5.3648 - val_mae: 5.8069
# Epoch 37/100
# 8/8 [==============================] - 1s 93ms/step - loss: 7.3999 - mae: 7.9383 - val_loss: 5.3187 - val_mae: 5.7741
# Epoch 38/100
# 8/8 [==============================] - 1s 101ms/step - loss: 7.4534 - mae: 7.9182 - val_loss: 5.2965 - val_mae: 5.7465
# Epoch 39/100
# 8/8 [==============================] - 1s 111ms/step - loss: 7.5912 - mae: 7.8987 - val_loss: 5.2320 - val_mae: 5.7051
# Epoch 40/100
# 8/8 [==============================] - 1s 112ms/step - loss: 7.5652 - mae: 7.8826 - val_loss: 5.1876 - val_mae: 5.6794
# Epoch 41/100
# 8/8 [==============================] - 1s 75ms/step - loss: 7.3066 - mae: 7.8621 - val_loss: 5.1901 - val_mae: 5.6589
# Epoch 42/100
# 8/8 [==============================] - 1s 90ms/step - loss: 7.4429 - mae: 7.8456 - val_loss: 5.1382 - val_mae: 5.6270
# Epoch 43/100
# Epoch 64/100
# 8/8 [==============================] - 1s 79ms/step - loss: 7.0409 - mae: 7.5820 - val_loss: 4.8208 - val_mae: 5.3044
# Epoch 65/100
# 8/8 [==============================] - 1s 79ms/step - loss: 7.0208 - mae: 7.5700 - val_loss: 4.8261 - val_mae: 5.2886
# Epoch 66/100
# 8/8 [==============================] - 1s 72ms/step - loss: 7.1479 - mae: 7.5588 - val_loss: 4.8284 - val_mae: 5.2838
# Epoch 67/100
# 8/8 [==============================] - 1s 84ms/step - loss: 6.8806 - mae: 7.5492 - val_loss: 4.8008 - val_mae: 5.2774
# Epoch 68/100
# 8/8 [==============================] - 1s 80ms/step - loss: 6.9868 - mae: 7.5378 - val_loss: 4.7592 - val_mae: 5.2528
# Epoch 69/100
# 8/8 [==============================] - 1s 77ms/step - loss: 6.9716 - mae: 7.5282 - val_loss: 4.7859 - val_mae: 5.2421
# Epoch 70/100
# 8/8 [==============================] - 1s 83ms/step - loss: 6.9645 - mae: 7.5182 - val_loss: 4.7768 - val_mae: 5.2331
# Epoch 71/100
# 8/8 [==============================] - 1s 86ms/step - loss: 7.0653 - mae: 7.5079 - val_loss: 4.7302 - val_mae: 5.2293
# Epoch 72/100
# 8/8 [==============================] - 1s 79ms/step - loss: 6.8699 - mae: 7.4956 - val_loss: 4.7526 - val_mae: 5.2227
# Epoch 73/100
# 8/8 [==============================] - 1s 97ms/step - loss: 7.1798 - mae: 7.4850 - val_loss: 4.7154 - val_mae: 5.2078
# Epoch 74/100
# 8/8 [==============================] - 1s 89ms/step - loss: 7.1218 - mae: 7.4752 - val_loss: 4.7086 - val_mae: 5.1979
# Epoch 75/100
# 8/8 [==============================] - 1s 84ms/step - loss: 6.9756 - mae: 7.4641 - val_loss: 4.6979 - val_mae: 5.1908
# Epoch 76/100
# 8/8 [==============================] - 1s 79ms/step - loss: 6.9795 - mae: 7.4518 - val_loss: 4.7158 - val_mae: 5.1820
# Epoch 77/100
# 8/8 [==============================] - 1s 88ms/step - loss: 6.9346 - mae: 7.4390 - val_loss: 4.6913 - val_mae: 5.1789
# Epoch 78/100
# 8/8 [==============================] - 1s 78ms/step - loss: 6.8171 - mae: 7.4262 - val_loss: 4.6946 - val_mae: 5.1787
# Epoch 79/100
# 8/8 [==============================] - 1s 85ms/step - loss: 7.0004 - mae: 7.4147 - val_loss: 4.6799 - val_mae: 5.1807
# Epoch 80/100
# 8/8 [==============================] - 1s 86ms/step - loss: 6.8610 - mae: 7.4021 - val_loss: 4.6993 - val_mae: 5.1575
# Epoch 81/100
# 8/8 [==============================] - 1s 99ms/step - loss: 7.0074 - mae: 7.3882 - val_loss: 4.6544 - val_mae: 5.1465
# Epoch 82/100
# 8/8 [==============================] - 1s 96ms/step - loss: 7.1745 - mae: 7.3745 - val_loss: 4.6401 - val_mae: 5.1339
# Epoch 83/100
# 8/8 [==============================] - 1s 89ms/step - loss: 6.8310 - mae: 7.3619 - val_loss: 4.6699 - val_mae: 5.1250
# Epoch 84/100
# 8/8 [==============================] - 1s 130ms/step - loss: 6.8646 - mae: 7.3473 - val_loss: 4.6430 - val_mae: 5.1271
# Epoch 85/100
# 8/8 [==============================] - 1s 106ms/step - loss: 6.8071 - mae: 7.3313 - val_loss: 4.6562 - val_mae: 5.1180
# Epoch 86/100
# 8/8 [==============================] - 1s 102ms/step - loss: 6.7352 - mae: 7.3146 - val_loss: 4.6365 - val_mae: 5.1162
# Epoch 87/100
# 8/8 [==============================] - 1s 90ms/step - loss: 6.6816 - mae: 7.2993 - val_loss: 4.6425 - val_mae: 5.1264
# Epoch 88/100
# 8/8 [==============================] - 1s 87ms/step - loss: 6.7346 - mae: 7.2830 - val_loss: 4.6102 - val_mae: 5.1163
# Epoch 89/100
# 8/8 [==============================] - 1s 122ms/step - loss: 6.8889 - mae: 7.2650 - val_loss: 4.6047 - val_mae: 5.0960
# Epoch 90/100
# 8/8 [==============================] - 1s 108ms/step - loss: 6.8086 - mae: 7.2450 - val_loss: 4.5760 - val_mae: 5.0695
# Epoch 91/100
# 8/8 [==============================] - 1s 94ms/step - loss: 6.7639 - mae: 7.2261 - val_loss: 4.5484 - val_mae: 5.0639
# Epoch 92/100
# 8/8 [==============================] - 1s 100ms/step - loss: 6.6549 - mae: 7.2049 - val_loss: 4.5807 - val_mae: 5.0580
# Epoch 93/100
# 8/8 [==============================] - 1s 93ms/step - loss: 6.7804 - mae: 7.1849 - val_loss: 4.5713 - val_mae: 5.0526
# Epoch 94/100
# 8/8 [==============================] - 1s 105ms/step - loss: 6.6649 - mae: 7.1616 - val_loss: 4.5475 - val_mae: 5.0519
# Epoch 95/100
# 8/8 [==============================] - 1s 97ms/step - loss: 6.6953 - mae: 7.1386 - val_loss: 4.5687 - val_mae: 5.0602
# Epoch 96/100
# 8/8 [==============================] - 1s 70ms/step - loss: 6.6800 - mae: 7.1148 - val_loss: 4.5729 - val_mae: 5.0307
# Epoch 97/100
# 8/8 [==============================] - 1s 69ms/step - loss: 6.6030 - mae: 7.0911 - val_loss: 4.5793 - val_mae: 5.0240
# Epoch 98/100
# 8/8 [==============================] - 1s 74ms/step - loss: 6.4898 - mae: 7.0608 - val_loss: 4.5211 - val_mae: 5.0322
# Epoch 99/100
# 8/8 [==============================] - 1s 68ms/step - loss: 6.6089 - mae: 7.0328 - val_loss: 4.5636 - val_mae: 5.0615
# Epoch 100/100
# 8/8 [==============================] - 1s 72ms/step - loss: 6.4301 - mae: 7.0014 - val_loss: 4.5380 - val_mae: 5.0395

# %%
model = keras.models.load_model("my_checkpoint.h5")

# %%
model.reset_states()
# We're forecasting on complete series and then cropping out only the validation part for plotting
cnn_forecast = model.predict(series[np.newaxis,:,np.newaxis])[0,split_time-1:-1,0]

# %%
plt.figure(figsize=(10,10))
plot_series(time_valid,x_valid,label="Series")
plot_series(time_valid,rnn_forecast,label="Forecast")

keras.metrics.mean_absolute_error(x_valid,rnn_forecast).numpy()
# MAE is 4.54 :) Best Model So far
# Out:
# 4.5491962
